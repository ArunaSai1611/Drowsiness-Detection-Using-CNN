# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model
import time
import winsound
import pyttsx3
from collections import deque


model = load_model('driver_drowsiness.h5', compile=False)


yawn_last_detected_time = 0
yawn_detection_cooldown = 3
drowsiness_start_time = None
drowsiness_alert_triggered = False
DROWSINESS_ALERT_TIMEOUT = 10
eye_state_buffer = deque(maxlen=5)
mp_face_mesh = mp.solutions.face_mesh
yawn_timestamps = []
sliding_window_duration = 60
yawn_count_threshold = 3


def extract_eye_region(frame, landmarks, eye_indices, margin=5):
    eye_points = [(int(landmarks[i].x * frame.shape[1]), int(landmarks[i].y * frame.shape[0])) for i in eye_indices]
    x_coords = [p[0] for p in eye_points]
    y_coords = [p[1] for p in eye_points]
    x_min, x_max = max(min(x_coords) - margin, 0), min(max(x_coords) + margin, frame.shape[1])
    y_min, y_max = max(min(y_coords) - margin, 0), min(max(y_coords) + margin, frame.shape[0])
    return frame[y_min:y_max, x_min:x_max]

def preprocess_eye_frame(frame):
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    with mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5) as face_mesh:
        results = face_mesh.process(frame_rgb)
        if results.multi_face_landmarks:
            for face_landmarks in results.multi_face_landmarks:
                left_eye_indices = [33, 160, 158, 133, 153, 144]
                right_eye_indices = [362, 385, 387, 263, 373, 380]
                left_eye = extract_eye_region(frame, face_landmarks.landmark, left_eye_indices, margin=10)
                right_eye = extract_eye_region(frame, face_landmarks.landmark, right_eye_indices, margin=10)
                if left_eye is not None and right_eye is not None:
                    return cv2.resize(left_eye, (150, 150)), cv2.resize(right_eye, (150, 150)), face_landmarks  
        return None, None, None 

def calculate_lip_distance(landmarks, frame_shape):
    upper_lip = (int(landmarks.landmark[13].x * frame_shape[1]), int(landmarks.landmark[13].y * frame_shape[0]))
    lower_lip = (int(landmarks.landmark[14].x * frame_shape[1]), int(landmarks.landmark[14].y * frame_shape[0]))
    distance = np.linalg.norm(np.array(upper_lip) - np.array(lower_lip))
    return distance

def preprocess_image_for_yawn(frame):
    face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    faces = face_classifier.detectMultiScale(frame, scaleFactor=1.3, minNeighbors=5)
    for (x, y, w, h) in faces:
        face = frame[y:y+h, x:x+w]
        resized_face = cv2.resize(face, (150, 150)) / 255.0
        return np.expand_dims(resized_face, axis=0), (x, y, w, h)
    return None, None  

def text_to_speech(text):
    engine = pyttsx3.init()
    engine.setProperty('rate', 150)
    engine.setProperty('volume', 1.0)
    engine.say(text)
    engine.runAndWait()

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    drowsiness_detected = False
    left_eye_resized, right_eye_resized, face_landmarks = preprocess_eye_frame(frame)

    
    if left_eye_resized is not None:
        processed_eye_frame = np.expand_dims(left_eye_resized, axis=0) / 255.0
        prediction = model.predict(processed_eye_frame)[0]
        labels = ['Closed', 'Open', 'no_yawn', 'yawn']
        predicted_label = labels[np.argmax(prediction)]
        eye_state_buffer.append(predicted_label)

        if eye_state_buffer.count("Closed") > 3:
            if drowsiness_start_time is None:
                drowsiness_start_time = time.time()
            elif time.time() - drowsiness_start_time >= 2:
                drowsiness_detected = True
        else:
            drowsiness_start_time = None

        cv2.putText(frame, f"Prediction: {predicted_label}", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    if drowsiness_detected and not drowsiness_alert_triggered:
        cv2.putText(frame, "DROWSINESS DETECTED", (10, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
        winsound.Beep(2000, 1000)

    
    if face_landmarks is not None:
        lip_distance = calculate_lip_distance(face_landmarks, frame.shape)
        lip_color = (0, 0, 255) if lip_distance > 14 else (0, 255, 0)
        cv2.putText(frame, f"Lip Distance: {lip_distance:.2f}", (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 1, lip_color, 2)

    processed_frame, face_coords = preprocess_image_for_yawn(frame)
    current_time = time.time()
    lip_yawn_detected = False

    if processed_frame is not None:
        yawn_probability = model.predict(processed_frame)[0][3]
        if face_landmarks and lip_distance > 19 and (current_time - yawn_last_detected_time) >= yawn_detection_cooldown:
            lip_yawn_detected = True
            yawn_last_detected_time = current_time
            yawn_timestamps.append(current_time)

        yawn_timestamps = [t for t in yawn_timestamps if current_time - t <= sliding_window_duration]
        yawn_count = len(yawn_timestamps)

        if lip_yawn_detected:
            cv2.putText(frame, "Yawning Detected!", (300, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
            if face_coords:
                x, y, w, h = face_coords
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
            if yawn_count > yawn_count_threshold:
                text_to_speech("You yawned multiple times. Please take a break.")
                yawn_timestamps = []
        else:
            cv2.putText(frame, "No Yawning", (300, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Vertical yawn bar at corner
        bar_x, bar_y, bar_w, bar_h = frame.shape[1] - 60, 10, 30, 300
        bar_fill = int((yawn_count / yawn_count_threshold) * bar_h)
        bar_fill = min(bar_fill, bar_h)
        cv2.rectangle(frame, (bar_x, bar_y), (bar_x + bar_w, bar_y + bar_h), (200, 200, 200), 2)
        cv2.rectangle(frame, (bar_x, bar_y + bar_h - bar_fill), (bar_x + bar_w, bar_y + bar_h), (0, 0, 255), -1)

    
        cv2.putText(frame, f"Yawns in 60s: {yawn_count}", (bar_x - 180, bar_y + bar_h + 25), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
    else:
        cv2.putText(frame, "Face Not Detected", (100, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    cv2.imshow("Driver Drowsiness Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\kanak\AppData\Roaming\Python\Python311\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# ...
